# %% [markdown]
# Name : Hidayah Husnul Khotimah | Username : hidayahhk | Email : hidayahhk@gmail.com

# %%
# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip \
  -O /tmp/rockpaperscissors.zip
# Out:
# --2021-07-03 09:04:29--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322873683 (308M) [application/zip]
# Saving to: ‘/tmp/rockpaperscissors.zip’
#
# /tmp/rockpapersciss 100%[===================>] 307.92M  11.5MB/s    in 31s
#
# 2021-07-03 09:05:01 (10.0 MB/s) - ‘/tmp/rockpaperscissors.zip’ saved [322873683/322873683]

# %%
import zipfile,os

local_zip = '/tmp/rockpaperscissors.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
! pip install split-folders
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
import splitfolders 

splitfolders.ratio('/tmp/rockpaperscissors/rps-cv-images', output="/tmp/rockpaperscissors/rps-cv-images/dataset-output", seed=42, ratio=(0.6,0.4), group_prefix=None)
# Out:
# Copying files: 2188 files [00:00, 4573.87 files/s]

# %%
base_dir_new = '/tmp/rockpaperscissors/rps-cv-images/dataset-output'
train_dir_new = os.path.join(base_dir_new,'train')
validation_dir_new = os.path.join(base_dir_new, 'val')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')
 
test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir_new,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
 
validation_generator = test_datagen.flow_from_directory(
        validation_dir_new,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 1312 images belonging to 3 classes.
# Found 876 images belonging to 3 classes.

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='sigmoid')
])

# %%
initial_learning_rate = 0.01
epochs = 50
decay = initial_learning_rate / epochs

def lr_time_based_decay(epoch, lr):
    return lr * 1 / (1 + decay * epoch)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=25,
      epochs=50,
      validation_data=validation_generator,
      validation_steps=5,
      callbacks=[tf.keras.callbacks.LearningRateScheduler(lr_time_based_decay, verbose=2)])
# Out:
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 25/25 [==============================] - 39s 265ms/step - loss: 1.2153 - accuracy: 0.4087 - val_loss: 0.8999 - val_accuracy: 0.7437
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009998000874799553.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.8530 - accuracy: 0.6413 - val_loss: 0.8061 - val_accuracy: 0.6062
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009994002858602087.
# 25/25 [==============================] - 7s 261ms/step - loss: 0.4176 - accuracy: 0.8550 - val_loss: 0.2833 - val_accuracy: 0.9125
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009988009951623015.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.3674 - accuracy: 0.8725 - val_loss: 0.3253 - val_accuracy: 0.9000
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009980025676285312.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.2471 - accuracy: 0.9125 - val_loss: 0.2937 - val_accuracy: 0.8938
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009970055878177272.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.2765 - accuracy: 0.9000 - val_loss: 0.4164 - val_accuracy: 0.8625
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000995810639821633.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.2081 - accuracy: 0.9287 - val_loss: 0.5588 - val_accuracy: 0.8313
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009944184235179403.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.1512 - accuracy: 0.9438 - val_loss: 0.2015 - val_accuracy: 0.9375
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009928298706840426.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1696 - accuracy: 0.9463 - val_loss: 0.1614 - val_accuracy: 0.9563
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009910460285594016.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1160 - accuracy: 0.9575 - val_loss: 0.2870 - val_accuracy: 0.9375
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009890679435473598.
# 25/25 [==============================] - 7s 261ms/step - loss: 0.1462 - accuracy: 0.9538 - val_loss: 0.1703 - val_accuracy: 0.9250
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009868967773757446.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1116 - accuracy: 0.9650 - val_loss: 0.0669 - val_accuracy: 0.9688
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009845339231184147.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.0851 - accuracy: 0.9750 - val_loss: 0.1646 - val_accuracy: 0.9812
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009819807727376596.
# 25/25 [==============================] - 7s 268ms/step - loss: 0.1428 - accuracy: 0.9638 - val_loss: 0.1195 - val_accuracy: 0.9625
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009792389492658468.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.1767 - val_accuracy: 0.9563
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009763100744408007.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.1510 - accuracy: 0.9737 - val_loss: 0.1581 - val_accuracy: 0.9688
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009731958267290851.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0524 - accuracy: 0.9837 - val_loss: 0.1229 - val_accuracy: 0.9812
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009698981733111679.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0884 - accuracy: 0.9712 - val_loss: 0.3309 - val_accuracy: 0.9438
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0009664190797994173.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0450 - accuracy: 0.9950 - val_loss: 0.1165 - val_accuracy: 0.9625
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009627605682269739.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.0476 - accuracy: 0.9875 - val_loss: 0.2090 - val_accuracy: 0.9312
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009589248909188279.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0389 - accuracy: 0.9912 - val_loss: 0.0466 - val_accuracy: 0.9750
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009549142404414344.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.1479 - accuracy: 0.9750 - val_loss: 0.1378 - val_accuracy: 0.9688
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0009507310394255563.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0381 - accuracy: 0.9862 - val_loss: 0.0448 - val_accuracy: 0.9812
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0009463777085727261.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 0.2392 - val_accuracy: 0.9688
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009418567825163638.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0538 - accuracy: 0.9875 - val_loss: 0.1153 - val_accuracy: 0.9688
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009371709097084122.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0615 - accuracy: 0.9837 - val_loss: 0.2184 - val_accuracy: 0.9563
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009323228523061064.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0431 - accuracy: 0.9837 - val_loss: 0.0421 - val_accuracy: 0.9812
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009273153702688248.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0476 - accuracy: 0.9825 - val_loss: 0.0819 - val_accuracy: 0.9750
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009221513371272998.
# 25/25 [==============================] - 7s 265ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.0763 - val_accuracy: 0.9937
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009168336819986992.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.0514 - accuracy: 0.9862 - val_loss: 0.1288 - val_accuracy: 0.9750
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009113655052523668.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.0388 - accuracy: 0.9900 - val_loss: 0.1729 - val_accuracy: 0.9750
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0009057498469436365.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0181 - accuracy: 0.9950 - val_loss: 0.1501 - val_accuracy: 0.9812
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0008999899182237673.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.0428 - accuracy: 0.9900 - val_loss: 0.1545 - val_accuracy: 0.9812
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0008940889276919404.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0310 - accuracy: 0.9912 - val_loss: 0.2372 - val_accuracy: 0.9625
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0008880501970268393.
# 25/25 [==============================] - 6s 261ms/step - loss: 0.0253 - accuracy: 0.9925 - val_loss: 0.0719 - val_accuracy: 0.9812
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0008818770452682762.
# 25/25 [==============================] - 7s 261ms/step - loss: 0.0164 - accuracy: 0.9925 - val_loss: 0.0650 - val_accuracy: 0.9688
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0008755729044029359.
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0670 - accuracy: 0.9825 - val_loss: 0.0661 - val_accuracy: 0.9750
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0008691412614721709.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.1685 - val_accuracy: 0.9812
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0008625856007487409.
# 25/25 [==============================] - 7s 261ms/step - loss: 0.0901 - accuracy: 0.9812 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.000855909519253872.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0142 - accuracy: 0.9937 - val_loss: 0.0131 - val_accuracy: 0.9937
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0008491166111540109.
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.0707 - val_accuracy: 0.9812
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0008422104677636575.
# 25/25 [==============================] - 7s 267ms/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.2626 - val_accuracy: 0.9750
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0008351948507165611.
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0102 - accuracy: 0.9975 - val_loss: 0.1668 - val_accuracy: 0.9688
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0008280734032401367.
# 25/25 [==============================] - 7s 261ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9937
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0008208499387723471.
# 25/25 [==============================] - 7s 264ms/step - loss: 0.0470 - accuracy: 0.9950 - val_loss: 0.0104 - val_accuracy: 0.9937
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0008135282100391519.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0030 - accuracy: 0.9975 - val_loss: 0.1281 - val_accuracy: 0.9750
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0008061119667916981.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0067 - accuracy: 0.9962 - val_loss: 0.0127 - val_accuracy: 0.9875
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0007986050711404764.
# 25/25 [==============================] - 7s 266ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.0199 - val_accuracy: 0.9875
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0007910113821356674.
# 25/25 [==============================] - 7s 268ms/step - loss: 0.0590 - accuracy: 0.9862 - val_loss: 0.1002 - val_accuracy: 0.9750
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0007833346981274111.
# 25/25 [==============================] - 7s 263ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0788 - val_accuracy: 0.9812

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(13, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss')
plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  print(fn)
  if classes [0,0] == 0:
    print('rock')
  elif classes [0,1] == 0:
    print('scissors')
  else:
    print('paper')
# Out:
#      <input type="file" id="files-c7f8f5f7-ead8-428f-92bf-5f9723e8c6ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7f8f5f7-ead8-428f-92bf-5f9723e8c6ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.jfif to download.jfif
# download.jfif
# scissors
